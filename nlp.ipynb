# %% [markdown]
# <a href="https://colab.research.google.com/github/payal500/practice-series-/blob/main/nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NLP:
# Common NLP Task:
#
# *  Information retrival - ex from a document we extract import information like name, address , conctent
# *  Test/Document Retrival
# *  sentiment analysis
# *  parts of speech tagging - i am the happy person , so convert into part of speech like i as verb so its easy to learn for manchine
# *   language detection and machine translation - google translater
# *   conversational agents - chatbots like speech and text contain
# *   text sumarization- short summary of content
# *   text generation -  auto mactic text generate using your previous behaviour
# *   spell checkimg and grammer correction - checking speeling in content and give suggestion
# *   speech to text - convert speech content to text

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Approches to nlp :
#
# 1. **heruistic model**: in this we create rule on variours pattern its diifcult to manage all data rule
#
# 2- **ml approach**- its advanced than heruistic we use textvectorizaion taht auto convert text data into numeric
#
# 3- **dl approach **- is best approch comapre to ml as when we convert text to numeric it loose series of  data , ex- hi i am payal and it change data in numeric in same series

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tokenization:-1 sentence, 2. word
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
